# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:https://www.kaggle.com/datasets/shivamb/netflix-shows
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import numpy as np 
from sklearn.ensemble import IsolationForest
import seaborn as sns 
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
data=pd.read_csv('netflix_titles.csv')
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe() # Summary statistics of numerical variables
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
Checking for missing values:
# Out:
#   Cell In[8], line 1
#     Checking for missing values:
#              ^
# SyntaxError: invalid syntax

# %%
data.isnull().sum()

# %%
Handling Missing Values:

# %%
data.dropna()  # Drop rows with missing values
data['director'] = data['director'].fillna("No Data Available")
data['cast'] = data['cast'].fillna("No Data Available")
data['country'] = data['country'].fillna("No Data Available")
data['date_added']=data['date_added'].fillna(data['date_added'].mode()[0])          
data['rating']=data['rating'].fillna(data['rating'].mode()[0])      
data['duration']=data['duration'].fillna('No Data Available')  
data

# %%
#read csv file
df=pd.read_csv('netflix_titles.csv')
print(df)

#missing_data = df.isnull().sum()

#print("Columns with missing data:")
#print(missing_data[missing_data > 0])

#df = df.dropna(subset=['country'])
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
df=pd.read_csv('netflix_titles.csv')

features = df[['release_year']]

model = IsolationForest(contamination=0.05, random_state=42)

outliers = model.fit_predict(features)

df['outlier'] = outliers

plt.scatter(df['release_year'], np.zeros_like(df['release_year']), c=df['outlier'], cmap='viridis')
plt.xlabel('Release Year')
plt.title('Outlier Detection in Dataset')
plt.show()

outlier_df = df[df['outlier'] == -1]
print("Outliers:")
print(outlier_df)
# Out:
# C:\Users\keert\OneDrive\Documents\a\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Outliers:
#      show_id   type                                title          director  \
# 7         s8  Movie                              Sankofa      Haile Gerima
# 22       s23  Movie                      Avvai Shanmughi    K.S. Ravikumar
# 41       s42  Movie                                 Jaws  Steven Spielberg
# 42       s43  Movie                               Jaws 2    Jeannot Szwarc
# 43       s44  Movie                               Jaws 3         Joe Alves
# ...      ...    ...                                  ...               ...
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory        Mel Stuart
# 8748   s8749  Movie                 Winter of Our Dreams       John Duigan
# 8763   s8764  Movie      WWII: Report from the Aleutians       John Huston
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
duplicates = data[data.duplicated()]

data1 = data.drop_duplicates()
data1
# Out:
#      show_id     type                  title           director  \
# 0         s1    Movie   Dick Johnson Is Dead    Kirsten Johnson
# 1         s2  TV Show          Blood & Water  No Data Available
# 2         s3  TV Show              Ganglands    Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  No Data Available
# 4         s5  TV Show           Kota Factory  No Data Available
# ...      ...      ...                    ...                ...
# 8802   s8803    Movie                 Zodiac      David Fincher
# 8803   s8804  TV Show            Zombie Dumb  No Data Available
# 8804   s8805    Movie             Zombieland    Ruben Fleischer
# 8805   s8806    Movie                   Zoom       Peter Hewitt
# 8806   s8807    Movie                 Zubaan        Mozez Singh
#
#                                                    cast            country  \
# 0                                     No Data Available      United States
# ...

# %%
data['type'].value_counts() #Count of categories in categorical variables:
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
# dividing into movies and tv shows
type_movie,type_show = data[data['type']=='Movie'],data[data['type']=='TV Show']

# %%
type_movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
import datetime as dt
data['date_added_date'] = pd.to_datetime(data['date_added'])

# %%
sum(data['date_added_date'].dt.year < data['release_year'])
# Out:
# 14

# %%
data.loc[(data['date_added_date'].dt.year < data['release_year']),['date_added_date','release_year']]
# Out:
#      date_added_date  release_year
# 1551      2020-12-14          2021
# 1696      2020-11-15          2021
# 2920      2020-02-13          2021
# 3168      2019-12-06          2020
# 3287      2019-11-13          2020
# 3369      2019-10-25          2020
# 3433      2019-10-11          2020
# 4844      2018-05-30          2019
# 4845      2018-05-29          2019
# 5394      2017-07-01          2018
# 5658      2016-12-23          2018
# 5677      2016-12-13          2017
# 7063      2018-10-26          2019
# 7112      2013-03-31          2016

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset? - Yes
# 2. Did the process of cleaning your data give you new insights into your dataset? - Yes, by identifying and addressing issues like missing values, duplicates, outliers gained a clearer understanding of the data quality.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations? - Need to address missing values, duplicates and outliers appropriately before analysis and ensure the datatypes and handle any inconsistencies or errors in the dataset
